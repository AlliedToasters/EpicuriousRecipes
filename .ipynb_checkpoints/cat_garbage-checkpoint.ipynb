# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
# %matplotlib inline

# %% [markdown]
# Epicurious data from [Kaggle](https://www.kaggle.com/hugodarwood/epirecipes).

# %%
raw_data = pd.read_csv('epi_r.csv')
full = pd.read_json('full_format_recipes.json')

missing = []
for row in raw_data.index:
    if raw_data.loc[row].title not in list(full.title):
        missing.append(row)
        
for row in missing:
    print('dropping {} rows...'.format(len(missing)))
    raw_data = raw_data.drop(row)
    
full_ind = []
for row in raw_data.index:
    full_ind.append(list(full[full.title==raw_data.loc[row].title].index)[0])
    
categories = []
directions = []
ingredients = []
for i in full_ind:
    row = full.loc[i]
    cat, dr, ing = row.categories, row.directions, row.ingredients
    categories.append(cat)
    directions.append(dr)
    ingredients.append(ing)
    
raw_data['full_cats'] = categories
raw_data['full_dir'] = directions
raw_data['full_ingr'] = ingredients

# %%
raw_data[['title', 'rating', '#cakeweek']].head()
# Out:
#                                          title  rating  #cakeweek
# 0              Lentil, Apple, and Turkey Wrap    2.500        0.0
# 1  Boudin Blanc Terrine with Red Onion Confit    4.375        0.0
# 2                Potato and Fennel Soup Hodge    3.750        0.0
# 3             Mahi-Mahi in Tomato Olive Sauce    5.000        0.0
# 4                    Spinach Noodle Casserole    3.125        0.0

# %%
nutrients = ['calories', 'protein', 'fat', 'sodium']
bin_fts = []
for col in raw_data.columns:
    if col not in ['title', 'rating'] + nutrients:
        bin_fts.append(col)

# %%
categories = {}

remaining_ft = bin_fts.copy()
states = 'Alabama · Alaska · Arizona · Arkansas · California · Colorado · Connecticut · Delaware · Florida · Georgia · Hawaii · Idaho · Illinois · Indiana · Iowa · Kansas · Kentucky · Louisiana · Maine · Maryland · Massachusetts · Michigan · Minnesota · Mississippi · Missouri · Montana · Nebraska · Nevada · New Hampshire · New Jersey · New Mexico · New York · North Carolina · North Dakota · Ohio · Oklahoma · Oregon · Pennsylvania · Rhode Island · South Carolina · South Dakota · Tennessee · Texas · Utah · Vermont · Virginia · Washington · West Virginia · Wisconsin · Wyoming'
states = states.lower().split(' · ')

cities = list(pd.read_csv('cities.csv', engine='python')['city'])
cities.append('yonkers')
cities = [ct.lower() for ct in cities]

countries = list(pd.read_csv('countries.csv', header=None, engine='python')[0])
countries = [cn.split(' -')[0].lower() for cn in countries]

categories['states'] = states

categories['cities'] = cities

categories['countries'] = countries

geo_ft = states + cities + countries

# %%
fruit = 'Apple · Apricot · Banana · Bilberry · Blackberry · Blackcurrant · Blueberry · Coconut · Currant · Cherry · Cherimoya · Clementine · Cloudberry  · Date · Damson · Durian · Elderberry · Fig · Feijoa · Gooseberry · Grape · Grapefruit · Huckleberry · Jackfruit · Jambul · Jujube · Kiwifruit · Kumquat · Lemon · Lime · Loquat · Lychee · Mango · Melon · Cantaloupe · Honeydew · Watermelon · Rock melon · Nectarine · Orange · Passionfruit · Peach · Pear · Plum · Plumcot · Prune · Pineapple · Pomegranate · Pomelo · Purple mangosteen · Raisin · Raspberry · Rambutan · Redcurrant · Satsuma · Strawberry · Tangerine · Tomato · Ugli Fruit ·'
fruit = fruit.lower().split(' · ')
fruit.append('fruit')
fruit.append('cranberry')
fruit.append('berry')
fruit.append('citrus')
fruit.append('passion fruit')
fruit.append('persimmon')
fruit.append('dried fruit')
fruit.append('guava')
fruit.append('kiwi')
fruit.append('papaya')
fruit.append('quince')
categories['fruit'] = fruit

veggie = list(pd.read_csv('veggies.csv', sep='!!', engine='python')['veggies'])
veggie = [veg.lower() for veg in veggie]
categories['veggies'] = veggie

greens = list(pd.read_csv('greens.csv', engine='python')['name'])
greens = [grn.lower() for grn in greens]
categories['greens'] = greens

legumes = list(pd.read_csv('legumes.csv', engine='python')['legumes'])
legumes = [leg.lower() for leg in legumes]
legumes.append('bean')
categories['legumes'] = legumes

meat = [
    'meat',
    'beef',
    'pork',
    'venison',
    'veal',
    'ham',
    'ribs',
    'rib',
    'chicken',
    'poultry',
    'wings',
    'steak',
    'duck',
    'lamb',
    'buffalo',
    'meatball',
    'meatloaf',
    'rabbit',
    'sausage',
    'bacon',
    'brisket',
    'proscuitto',
    'prosciutto',
    'goose',
    'quail'
]
categories['meat'] = meat


seafood = [
    'seafood',
    'scallop',
    'trout',
    'tilapia',
    'snapper',
    'sardine',
    'octopus',
    'mussel',
    'oyster',
    'anchovy',
    'shrimp',
    'shellfish',
    'squid',
    'swordfish',
    'halibut',
    'caviar',
    'tuna',
    'lobster',
    'crab',
    'salmon',
    'fish',
    'bass',
    'clam',
    'cod'
]
categories['seafood'] = seafood

grains = list(pd.read_csv('grains.csv', engine='python')['grains'])
grains = [grain.lower() for grain in grains]
categories['grains'] = grains

pasta = list(pd.read_csv('pastas.csv', sep='!!', engine='python')['pastas'])
pasta = [pst.lower() for pst in pasta]
categories['pasta'] = pasta

cheese = list(pd.read_csv('cheese.csv', engine='python')['cheese'])
cheese = [chs.lower() for chs in cheese]
categories['cheese'] = cheese

dairy = [
    'dairy',
    'egg',
    'eggs',
    'cream',
    'milk',
    'butter',
    'mayonnaise'
]
categories['dairy'] = dairy

herbs_spices = list(pd.read_csv('herbs_spices.csv', sep='!!', engine='python')['herbs and spices'])
herbs_spices = [hs.split(' (')[0].lower() for hs in herbs_spices]
categories['herbs_spices'] = herbs_spices

nuts = list(pd.read_csv('nuts.csv')['nuts'])
nuts = [nt.lower() for nt in nuts]
categories['nuts'] = nuts

sweets = [
    'sweets',
    'chocolate',
    'créme de cacao',
    'cr��me de cacao',
    'coffee',
    'sugar',
    'hazelnut',
    'honey',
    'jam',
    'jelly',
    'jam or jelly',
    'syrup',
    'maple syrup',
    'molasses',
    'phyllo/puff pastry dough'
]
categories['sweets'] = sweets

alcohol = [
    'alcoholic',
    'amaretto',
    'aperitif',
    'bourbon',
    'brandy',
    'calvados',
    'campari',
    'cognac',
    'cognac/armagnac',
    'digestif',
    'wine',
    'grappa',
    'kirsch',
    'midori',
    'mezcal',
    'pernod',
    'port',
    'red wine',
    'white wine',
    'rum',
    'sake',
    'rosé',
    'sangria',
    'scotch',
    'tequila',
    'triple sec',
    'whiskey',
    'bitters',
    'chambord',
    'champagne',
    'chartreuse',
    'eau de vie',
    'frangelico',
    'gin',
    'grand marnier',
    'kahlúa',
    'liqueur',
    'sherry',
    'spirit',
    'vermouth',
    'vodka',
    'marsala'
]
categories['alcohol'] = alcohol



misc_descrip = [
    '#cakeweek',
    '#wasteless',
    '22-minute meals',
    '30 days of groceries',
    'advance prep required',
    'condiment',
    'condiment/spread',
    'cook like a diner',
    'cookbook critic',
    'edible gift',
    'epi + ushg', 
    'epi loves the microwave',
    'entertaining',
    'frankenrecipe',
    'freezer food',
    'gourmet',
    'harpercollins',
    'healthy',
    'high fiber',
    'house & garden',
    'kid-friendly',
    'kidney friendly',
    'kitchen olympics',
    'kosher',
    'one-pot meal',
    'organic',
    'paleo'
    'quick & easy',
    'quick and healthy',
    'tested & improved',
    'weelicious',
    'cookbooks',
    'leftovers',
    '3-ingredient recipes', 
    'bon appétit', 
    'bon app��tit', 
    'quick & easy', 
    'paleo',
    'self'
]
categories['misc_descrip'] = misc_descrip

people = [
    'anthony bourdain',
    'emeril lagasse',
    'nancy silverton',
    'suzanne goin'
]
categories['people'] = people

foods = [
    'food',
    'taco',
    'biscuit',
    'bread',
    'casserole/gratin',
    'chili',
    'burrito',
    'dip',
    'bread',
    'flat bread',
    'frittata',
    'hamburger',
    'hummus',
    'muffin',
    'omelet',
    'pickles',
    'pizza',
    'pot pie',
    'salad',
    'salad dressing',
    'salsa',
    'sandwich',
    'soup/stew',
    'sourdough',
    'soy',
    'soy sauce',
    'stew',
    'stock',
    'stuffing/dressing',
    'tortillas',
    'vinegar',
    'windsor',
    'yogurt',
    'sauce'
]
categories['foods'] = foods

breakfast = [
    'breakfast',
    'brunch',
    'crêpe',
    'muffin',
    'omelet',
    'pancake',
    'waffle',
    'quiche'
]
categories['breakfast'] = breakfast

lunch = [
    'lunch',
    'pickles',
    'mayo',
    'mustard',
    'mayonnaise',
    'soup/stew'
]
categories['lunch'] = lunch

dinner = [
    'dinner',
    'casserole/gratin',
    'chili',
    'burrito',
    'frittata',
    'hamburger',
    'pizza',
    'pot pie',
    'salad',
    'salad dressing',
    'stew',
    'stock',
    'stuffing/dressing',
    'tortillas',
    'soup/stew'
]
categories['dinner'] = dinner

snack = [
    'snack',
    'appetizer',
    'dip',
    "hors d'oeuvre",
    'hummus',
    'snack week'
]
categories['snack'] = snack

dessert = [
    'dessert',
    'cake',
    'brownie',
    'candy',
    'coffee',
    'cookie',
    'cookies',
    'crêpe',
    'cupcake',
    'custard',
    'fritter',
    'frozen dessert',
    'pastry',
    'pie',
    'sorbet',
    'ice cream',
    'soufflé/meringue',
    'tart'
]
categories['dessert'] = dessert

drinks = [
    'drink',
    'drinks',
    'cocktail',
    'coffee',
    'hot drink',
    'house cocktail',
    'iced coffee',
    'iced tea',
    'margarita',
    'martini',
    'mixer',
    'punch',
    'smoothie',
    'spritzer',
    'tea',
    'westwood'
]
categories['drinks'] = drinks

events = [
    'anniversary',
    'back to school',
    'backyard bbq',
    'bastille day',
    'birthday',
    'buffet',
    'camping',
    'christmas',
    'christmas eve',
    'cinco de mayo',
    'easter',
    'diwali',
    'engagement party',
    'family reunion',
    'fourth of july',
    'friendsgiving',
    'game',
    'graduation',
    'halloween',
    'hanukkah',
    'kentucky derby',
    'passover',
    'kosher for passover',
    'kwanzaa',
    'labor day',
    'lunar new year',
    'mardi gras',
    "mother's day",
    "new year's day",
    "new year's eve",
    'oktoberfest',
    'oscars',
    'pacific palisades',
    'parade',
    'party',
    'persian new year',
    'picnic',
    'poker/game night',
    'potluck',
    'purim',
    'ramadan',
    'rosh hashanah/yom kippur',
    'shavuot',
    'shower',
    'spring',
    "st. patrick's day",
    'sukkot',
    'summer',
    'super bowl',
    'tailgating',
    'thanksgiving',
    "valentine's day",
    'wedding',
    'winter',
    'fall'
]
categories['events'] = events

jewish = [
    'kosher',
    'hanukkah',
    'passover',
    'kosher for passover',
    'purim',
    'rosh hashanah/yom kippur',
    'shavuot',
    'sukkot'
]
categories['jewish'] = jewish

instructions = [
    'bake',
    'blender',
    'boil',
    'braise',
    'broil',
    'candy thermometer',
    'chill',
    'coffee grinder',
    'deep-fry',
    'double boiler',
    "father's day",
    'flaming hot summer',
    'food processor',
    'freeze/chill',
    'fry',
    'grill',
    'grill/barbecue',
    'juicer',
    'mandoline',
    'marinade',
    'marinate',
    'microwave',
    'mixer',
    'mortar and pestle',
    'pan-fry',
    'poach',
    'pressure cooker',
    'ramekin',
    'roast',
    'rub',
    'shower',
    'side',
    'simmer',
    'skewer',
    'slow cooker',
    'smoker',
    'steam',
    'stir fry',
    'wok',
    'sauté'
]
categories['instructions'] = instructions

nos = [
    'dairy free',
    'fat free',
    'low cal',
    'low carb',
    'low cholesterol',
    'low fat',
    'low sodium',
    'low sugar',
    'low/no sugar'
    'no meat, no problem',
    'no sugar added',
    'no-cook',
    'pescatarian',
    'raw',
    'soy free',
    'sugar conscious',
    'tree nut free',
    'vegan',
    'vegetarian',
    'wheat/gluten-free'
]
categories['nos'] = nos

# %%
for category in categories:
    new_cat = []
    for ngram in categories[category]:
        for ft in bin_fts:
            if ngram in ft:
                new_cat.append(ft)
    categories[category] = list(set(new_cat))
    
remaining_ft = bin_fts.copy()
    
print(len(remaining_ft))

for cat in categories:
    for feature in categories[cat]:
        if feature in remaining_ft:
            remaining_ft.remove(feature)
# Out:
# 674

# %%
raw_data['ft_count'] = raw_data[bin_fts].sum(axis=1) #Total number of binary features that each recipe has

for cat in categories:
    raw_data[cat+'_count'] = raw_data[categories[cat]].sum(axis=1)

#fig = plt.figure(figsize=(10, 10))
#for cat in categories:
#    plt.hist(raw_data[cat+'_count'], alpha=.5, label=cat)
#plt.legend();

# %%
ingr = [
    'fruit',
    'veggies',
    'greens',
    'legumes',
    'meat',
    'seafood',
    'dairy',
    'grains',
    'pasta',
    'cheese',
    'herbs_spices',
    'nuts',
    'sweets'
]
ingredients = []
for cat in ingr:
    ingredients += categories[cat]
ingredients = list(set(ingredients))

raw_data['ingredient_count'] = raw_data[ingredients].sum(axis=1)

# %%
plt.hist(raw_data['ft_count']);

# %%
raw_data['zero_rating'] = np.where(raw_data.rating == 0, 1, 0)
raw_data['4+_rating'] = np.where(raw_data.rating > 4, 1, 0)

print('ratings above zero: ', (len(raw_data[raw_data['zero_rating']==1])/len(raw_data)))
print('ratings above four: ', (len(raw_data[raw_data['4+_rating']==1])/len(raw_data)))
# Out:
# ratings above zero:  0.09156193895870736
# ratings above four:  0.5355076800319171

# %%
#print(categories.keys())
my_cats = [
    'sweets',
    'foods',
    'breakfast',
    'lunch',
    'dinner',
    'snack',
    'dessert',
    'alcohol',
    'nos'
]

# %%
svc = SVC(class_weight='balanced')
samp = raw_data.sample(frac=.1)

# %%
X = samp[['chocolate']]
Y = samp['4+_rating']

scores = pd.Series(cross_val_score(svc, X, Y, cv=5))
print(scores, '\n')
      
svc.fit(X, Y)
Y_ = svc.predict(X)
print(pd.crosstab(Y_, Y))
# Out:
# 0    0.517413
# 1    0.533666
# 2    0.526185
# 3    0.543641
# 4    0.445000
# dtype: float64
#
# 4+_rating    0     1
# row_0
# 0           37    35
# 1          897  1036

# %%
X = samp[['chocolate', 'alcohol_count']]
Y = samp['4+_rating']

scores = pd.Series(cross_val_score(svc, X, Y, cv=5))
print(scores, '\n')
      
svc.fit(X, Y)
Y_ = svc.predict(X)
print(pd.crosstab(Y_, Y))
# Out:
# 0    0.532338
# 1    0.558603
# 2    0.536160
# 3    0.551122
# 4    0.537500
# dtype: float64
#
# 4+_rating    0    1
# row_0
# 0          108   80
# 1          826  991

# %%
X = samp[['breakfast_count', 'lunch_count', 'dinner_count', 'dessert_count', 'snack_count']]
Y = samp['4+_rating']

scores = pd.Series(cross_val_score(svc, X, Y, cv=5))
print(scores, '\n')
      
svc.fit(X, Y)
Y_ = svc.predict(X)
print(pd.crosstab(Y_, Y))
# Out:
# 0    0.559701
# 1    0.546135
# 2    0.548628
# 3    0.536160
# 4    0.497500
# dtype: float64
#
# 4+_rating    0    1
# row_0
# 0          502  462
# 1          432  609

# %%
full = pd.read_json('full_format_recipes.json')

missing = []
for row in raw_data.index:
    if raw_data.loc[row].title not in list(full.title):
        missing.append(row)
        
for row in missing:
    print('dropping {} rows...'.format(len(missing)))
    raw_data = raw_data.drop(row)
    
full_ind = []
for row in raw_data.index:
    full_ind.append(list(full[full.title==raw_data.loc[row].title].index)[0])
    
categories = []
directions = []
ingredients = []
for i in full_ind:
    row = full.loc[i]
    cat, dr, ing = row.categories, row.directions, row.ingredients
    categories.append(cat)
    directions.append(dr)
    ingredients.append(ing)
    
raw_data['full_cats'] = categories
raw_data['full_dir'] = directions
raw_data['full_ingr'] = ingredients

# %%
# Out:
# ['Chocolate',
#  'Dessert',
#  'Bake',
#  'Kid-Friendly',
#  'Raspberry',
#  'Coconut',
#  'Chill',
#  'Gourmet']

# %%
def fix(raw_data, full):
    """This 'tabboo' recursive algorithm removes rows that don't match
    on the 'title' field until they do match, and then it returns the result.
    """
    for recp in full.index:
        if recp not in raw_data.index:
            full = full.drop(recp)
            full.index = range(0, len(full))
            break
        if full.loc[recp].title != raw_data.loc[recp].title:
            full = full.drop(recp)
            full.index = range(0, len(full))
            break
    if len(full) == len(raw_data):
        return raw_data, full
    else:
        return fix(raw_data, full)
    
raw_data, full = fix(raw_data, full)
# Out:
# 560
# 1010
# 1074
# 1132
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368
# 1368

# %%
full.loc[20000].title
# Out:
# 'Self-Starter '

# %%
'Self-Starter ' in list(raw_data.title)
# Out:
# True

# %%
raw_data.loc[200].title
# Out:
# 'Smoky Plantain Crema '

# %%
x = pd.DataFrame()
x.rows=[3,4,5,6]
x['things'] = [0, 2, 4, 6]

# %%
x.head()
# Out:
#    things
# 0       0
# 1       2
# 2       4
# 3       6

# %%
x = x.reindex()

# %%
x.head()
# Out:
#    things
# 0       0
# 1       2
# 2       4
# 3       6
